# %% [markdown]
# <a href="https://colab.research.google.com/github/mellily/Python-100-Days/blob/master/Assignments/Part%201/Assignment_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DSML investigation:
# ### You are part of the Suisse Impossible Mission Force, or SIMF for short. You need to uncover a rogue agent that is trying to steal sensitive information.
#
# ### Your mission, should you choose to accept it, is to find that agent before any classified information gets stolen. Good luck!

# %% [markdown]
# ## Assignment part one
#
# Airport security confiscated a laptop of a spy, which was later given to you. The laptop contains some documents that might be useful in the investigation process. You retrieve those documents and want to analyse them. Our intelligence shows that the person that we are looking for has visited the USA between Sept 2019 to Oct 2020. He is currently working undercover.
#
#
# ### Getting to know our data
#
# We have retrieved from the laptop the following file:
# - A list of suspects
# - The flight records of these potential suspects

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
userRecords = pd.read_csv("https://raw.githubusercontent.com/michalis0/DataScience_and_MachineLearning/refs/heads/master/Assignments/Part%201/data/userRecords.csv")
travelRecords = pd.read_csv("https://raw.githubusercontent.com/michalis0/DataScience_and_MachineLearning/refs/heads/master/Assignments/Part%201/data/flightRecords.csv")

# %%
userRecords
# Out:
#      UserID first_name  last_name  birthday country marital_status  \
# 0    317991      Lu***    Al*****  29.07.03      AR              1
# 1    241892     Ma****  Ro*******  10.11.99      AR              1
# 2    303376     Fr****     Ac****  25.07.84      AR              1
# 3    761992     Fr****      Go***  20.03.70      AR              1
# 4    373318      Jo***      Ro***  05.10.71      AR              1
# ..      ...        ...        ...       ...     ...            ...
# 952  218415   Bu******   Mo******  22.01.01      ZA              0
# 953  173906    Th*****   Mo******  06.11.61      ZA              0
# 954  178685    Mi*****  Bu*******  29.05.53      ZA              0
# 955  200865  Si*******     Na****  16.12.62      ZA              0
# 956  102637    Bo*****     Na****  24.02.50      ZA              0
#
#      number_of_kids               employment
# 0               2.0             Web Designer
# 1               0.0                   Banker
# 2               0.0            Kitchen staff
# 3               0.0       Teaching Assistant
# 4               0.0  Administrative employee
# ..              ...                      ...
# 952             1.0             Web Designer
# 953             2.0             Web Designer
# 954             1.0                Professor
# 955             0.0             Web Designer
# 956             NaN               Consultant
#
# [957 rows x 8 columns]

# %%
travelRecords[travelRecords["userID"] == 317991]
# Out:
#    flightName departure destination      date  userID
# 0     KX65826        AR          IT  20.01.10  317991
# 1     CL12336        IT          MT  16.06.10  317991
# 2    YN106988        MT          SE  08.05.11  317991
# 3     CB58289        SE          EE  08.11.11  317991
# 4    SX625101        EE          AZ  17.11.11  317991
# 5     FI81778        AZ          ES  19.01.12  317991
# 6     WL73165        ES          RU  24.02.12  317991
# 7    NG103876        RU          JP  28.06.12  317991
# 8     IX62714        JP          AT  24.07.12  317991
# 9     BT46823        AT          GB  25.08.12  317991
# 10   JC110193        GB          KR  12.09.12  317991
# 11   UF101853        KR          DZ  16.08.13  317991
# 12    LI26752        DZ          LU  29.11.13  317991
# 13    SX25878        LU          DE  07.03.14  317991
# 14    MT75485        DE          GT  02.04.14  317991
# 15   ZZ101384        GT          HU  18.10.14  317991
# 16    HZ12741        HU          BG  14.07.15  317991
# 17    VJ46313        BG          AR  09.06.16  317991
# 18   JM292310        AR          BR  19.10.16  317991
# 19   CQ210993        BR          CR  27.09.17  317991
# 20   PS311063        CR          CO  28.02.18  317991
# 21    UN91215        CO          KR  15.10.18  317991
# 22    CB93843        KR          MY  07.05.19  317991
# 23   PU341107        MY          CH  24.07.19  317991
# 24  OK7791010        CH          MD  01.10.19  317991
# 25    YQ81668        MD          PR  21.05.20  317991
# 26   PN128107        PR          RU  29.01.21  317991
# 27   MA710838        RU          IS  03.08.21  317991
# 28   KO815110        IS          LU  07.12.21  317991
# 29    TI18392        LU          TR  06.03.22  317991
# 30   HQ121043        TR          BD  03.07.22  317991
# 31    MH62591        BD          ZA  04.10.22  317991

# %% [markdown]
# #### Shape of the data
#
# Let's first check how many rows and columns (features) are in the user records

# %%
userRecords.shape
# Out:
# (957, 8)

# %% [markdown]
# **Q1. How many rows are there in the user records dataset?**

# %% [markdown]
# #### Check out the first few rows
# Print the first few rows of the user records dataset and check them. Note that to protect innocent people, the name of the suspects have been censored, those will be revealed once number of potential suspects decreases.

# %%
userRecords.head()
# Out:
#    UserID first_name  last_name  birthday country marital_status  \
# 0  317991      Lu***    Al*****  29.07.03      AR              1
# 1  241892     Ma****  Ro*******  10.11.99      AR              1
# 2  303376     Fr****     Ac****  25.07.84      AR              1
# 3  761992     Fr****      Go***  20.03.70      AR              1
# 4  373318      Jo***      Ro***  05.10.71      AR              1
#
#    number_of_kids               employment
# 0             2.0             Web Designer
# 1             0.0                   Banker
# 2             0.0            Kitchen staff
# 3             0.0       Teaching Assistant
# 4             0.0  Administrative employee

# %% [markdown]
# #### Column/feature names
# print the list of columns in the user records dataset.

# %%
userRecords.columns
# Out:
# Index(['UserID', 'first_name', 'last_name', 'birthday', 'country',
#        'marital_status', 'number_of_kids', 'employment'],
#       dtype='object')

# %% [markdown]
# #### Duplicates
# Check if there are any duplicate entries in the user records dataset.
#
# __Remark__: If there are two rows in the dataset that have the same value for __all of the columns__, we consider this as a duplicate.

# %%
userRecords[userRecords.duplicated()].head()
# Out:
#      UserID first_name last_name  birthday country marital_status  \
# 19   100684    Ma*****    Me****  17.06.76      AR            NaN
# 165  910382      Ni***    El****  21.03.75      AZ            NaN
# 290  610518    An*****  An******  15.02.53      DK              1
#
#      number_of_kids               employment
# 19              0.0  Administrative employee
# 165             0.0  Administrative employee
# 290             NaN                  Manager

# %% [markdown]
# Show all the duplicated rows in the user records dataset.
#
# __Hint:__ use the method `duplicated(keep=False)` to get all occurrences of the duplicated rows.

# %%
userRecords[userRecords.duplicated(keep=False)]
# Out:
#      UserID first_name last_name  birthday country marital_status  \
# 18   100684    Ma*****    Me****  17.06.76      AR            NaN
# 19   100684    Ma*****    Me****  17.06.76      AR            NaN
# 47   910382      Ni***    El****  21.03.75      AZ            NaN
# 165  910382      Ni***    El****  21.03.75      AZ            NaN
# 276  610518    An*****  An******  15.02.53      DK              1
# 290  610518    An*****  An******  15.02.53      DK              1
#
#      number_of_kids               employment
# 18              0.0  Administrative employee
# 19              0.0  Administrative employee
# 47              0.0  Administrative employee
# 165             0.0  Administrative employee
# 276             NaN                  Manager
# 290             NaN                  Manager

# %% [markdown]
# **Q2. Are there any duplicate entries in the user records dataset?**
#
# *Note: Duplicate entries refer to two or more rows where all the values across every column are identical.*

# %% [markdown]
# **Q3. How many duplicate entries are in the user records dataset?**
#
# (Remark: for instance: there are 2 duplicate "entries" in the following list: '1 ,2, 1, 3, 3, 4, 5'. It's 1 and 3).

# %% [markdown]
# Drop the duplicate entries in the user records dataset.

# %%
userRecords = userRecords.drop_duplicates()

# %% [markdown]
# ### Spies often use false identities with fabricated data.
#
# #### This suggests that if certain data points occur with statistically improbable frequency, they might be fabricated.
#
# In this part we are going to verify if there are birthdates that have been reused an unusual amount of times.

# %% [markdown]
# Let's first ensure that the birthday column in the user records dataset has the correct format (datetime):

# %%
userRecords.dtypes
# Out:
# UserID              int64
# first_name         object
# last_name          object
# birthday           object
# country            object
# marital_status     object
# number_of_kids    float64
# employment         object
# dtype: object

# %% [markdown]
# Convert the column `birthday` to datetime if necessary

# %%
userRecords['birthday'] = pd.to_datetime(userRecords['birthday'], format="%d.%m.%y")
# Out:
# /tmp/ipykernel_1789/2219712290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   userRecords['birthday'] = pd.to_datetime(userRecords['birthday'], format="%d.%m.%y")

# %% [markdown]
# Find the list of birthdays that are duplicated/reused in the dataset

# %%
userRecords[userRecords["birthday"].duplicated(keep=False)].sort_values("birthday")
# Out:
#      UserID  first_name       last_name   birthday country marital_status  \
# 666  771503     Ad*****         Me***** 1970-03-18      MX              0
# 305  264350      To****        Sm****** 1970-03-18      EE              1
# 501  231770       Po***           Ya*** 1970-04-06      IN              0
# 772  166980       Pa***        Ad****** 1970-04-06      PL              0
# 807  662472        Nu**         Ri***** 1975-01-28      PT              0
# 160  205381        Ma**         Pe***** 1975-01-28      CH              1
# 516  352848     Ko*****       Bj******* 1978-11-21      IS              1
# 370  325946      Ro****        Ma****** 1978-11-21      FR              0
# 150  790046   St*******          Sa**** 1983-03-15      CA              0
# 393  339524        An**           Br*** 1983-03-15      GB              1
# 481  350882         Pa*           Ke*** 1983-08-26      IE              1
# 723  722924     Pa*****         Br***** 1983-08-26      NL              0
# 46   848523       Gu***        Ba****** 1991-12-02      AZ            NaN
# 396  719655   El*******           Lo*** 1991-12-02      GT              1
# 668  428573        Ma**           Lo*** 1992-06-01      MX              0
# 647  405604    Li******          Ro**** 1992-06-01      MD              1
# 630  333547    St******  Ko************ 1992-06-01      MD              1
# 627  333546      Ма****          Se**** 1992-06-01      MD              1
# 592  410221  Ch********        Ho****** 1999-08-09      LU              0
# 538  486395        Ko**       Ma******* 1999-08-09      JP              0
# 557  161109          현주            Ba** 1999-09-12      KR              1
# 838  698469        Ол**       Ва******* 1999-09-12      RU              0
# 329  569511       So***           Go*** 2004-11-30      ES            NaN
# 13   660506        Ju**           Go*** 2004-11-30      AR              1
# 623  556033      Ма****         Tu***** 2054-03-26      MD              1
# 950  458293  No********        Wi****** 2054-03-26      ZA              1
# 186  425341      Mi****          Fl**** 2055-01-08      CL              1
# 209  233165     Ma*****       He******* 2055-01-08      CR            NaN
# 34   764821       So***            Ed** 2057-06-25      AT              0
# 355  641389        Mi**          Mä**** 2057-06-25      FI              1
# 241  752974      Mi****           No*** 2057-12-18      CZ              0
# 790  185759    Ar******           Ot*** 2057-12-18      PR            NaN
# 288  621691         نو*           Ka*** 2057-12-24      DZ              1
# 112  243358      Ге****         Iv***** 2057-12-24      BG              0
# 399  251964        Fl**         Mo***** 2060-03-26      GT            NaN
# 570  793023          미영             Se* 2060-03-26      KR              1
# 511  813808     Br*****  Si************ 2060-06-23      IS              0
# 715  400700        Ba**          De**** 2060-06-23      NL              0
# 722  856596     Ma*****         De***** 2062-07-07      NL            NaN
# 191  236456     Li*****          To**** 2062-07-07      CO              0
# 74   470030        Ka**           Ha*** 2067-07-24      BD            NaN
# 6    676003    Cr******       Ro******* 2067-07-24      AR              0
# 183  133154        Ro**         Fu***** 2068-09-22      CL              1
# 153  297653       Br***            Wo** 2068-09-22      CA              1
# 312  303568  An********            Ka** 2068-10-09      EE              0
# 810  441742       Pa***           Al*** 2068-10-09      PT              0
#
#      number_of_kids               employment
# 666             NaN       Teaching Assistant
# 305             NaN               Consultant
# 501             2.0                  Manager
# 772             1.0             Web Designer
# 807             2.0                Professor
# 160             0.0            Kitchen staff
# 516             0.0                  Manager
# 370             2.0                   Doctor
# 150             1.0                  Manager
# 393             1.0            Kitchen staff
# 481             NaN  Administrative employee
# 723             1.0             Web Designer
# 46              4.0       Teaching Assistant
# 396             0.0       Teaching Assistant
# 668             1.0             Web Designer
# 647             0.0            Kitchen staff
# 630             1.0       Teaching Assistant
# 627             1.0       Teaching Assistant
# 592             0.0       Teaching Assistant
# 538             1.0                   Banker
# 557             NaN                Professor
# 838             NaN                  Manager
# 329             3.0                   Banker
# 13              3.0                Librarian
# 623             2.0             Web Designer
# 950             2.0                Professor
# 186             0.0               Consultant
# 209             2.0       Teaching Assistant
# 34              4.0               Consultant
# 355             0.0                   Lawyer
# 241             NaN                Professor
# 790             3.0  Administrative employee
# 288             2.0                Librarian
# 112             NaN             Web Designer
# 399             2.0                Librarian
# 570             0.0                  Manager
# 511             1.0             Web Designer
# 715             NaN            Kitchen staff
# 722             1.0                  Manager
# 191             NaN                   Doctor
# 74              4.0                  Manager
# 6               0.0                   Lawyer
# 183             0.0                   Banker
# 153             0.0                   Lawyer
# 312             2.0                   Banker
# 810             2.0                  Manager

# %% [markdown]
# Let's count how many people have their birthday on the same day among the duplicated birthdays.

# %%
userRecords["birthday"].value_counts().sort_values(ascending = False).head()
# Out:
# birthday
# 1992-06-01    4
# 1975-01-28    2
# 2004-11-30    2
# 2057-12-18    2
# 1978-11-21    2
# Name: count, dtype: int64

# %% [markdown]
# **Q4. What is the most common birthday in the dataset?**

# %% [markdown]
# **Q5. How many users have their birthdays on that day (the most common birthday)?**

# %% [markdown]
# We can consider that there is no suspicious discrepancy through birthdays.

# %% [markdown]
# #### We have reasons to believe that the suspect works very thoroughly, so he would make sure that the fabricated data about his identity is complete in order for his operation to run smoothly.
# #### Therefore, we can exclude the people with incomplete information from the list of potential suspects.

# %% [markdown]
# Count how many null values are there in each column of the user records dataset. You can call `isnull()` and `sum()` to get a count of how many null values are there in each column.

# %%
userRecords.isnull().sum()
# Out:
# UserID              0
# first_name          1
# last_name           1
# birthday            1
# country             0
# marital_status    102
# number_of_kids    152
# employment          1
# dtype: int64

# %% [markdown]
# If you encounter any null values in the dataset, be sure to exclude those entries from the suspect list.

# %%
userRecords = userRecords.dropna()

# %% [markdown]
# ### Linking the user records to the flight records
#
# We will now proceed to identify the users who were in the USA from Sept 1st, 2019 to Oct 31st, 2020.
#
# We will merge the flight records with the user records in order to ensure that users who have been unsuspected in the previous step are not considered.

# %%
userRecords.head()
# Out:
#    UserID first_name  last_name   birthday country marital_status  \
# 0  317991      Lu***    Al***** 2003-07-29      AR              1
# 1  241892     Ma****  Ro******* 1999-11-10      AR              1
# 2  303376     Fr****     Ac**** 1984-07-25      AR              1
# 3  761992     Fr****      Go*** 1970-03-20      AR              1
# 4  373318      Jo***      Ro*** 1971-10-05      AR              1
#
#    number_of_kids               employment
# 0             2.0             Web Designer
# 1             0.0                   Banker
# 2             0.0            Kitchen staff
# 3             0.0       Teaching Assistant
# 4             0.0  Administrative employee

# %%
travelRecords.head()
# Out:
#   flightName departure destination      date  userID
# 0    KX65826        AR          IT  20.01.10  317991
# 1    CL12336        IT          MT  16.06.10  317991
# 2   YN106988        MT          SE  08.05.11  317991
# 3    CB58289        SE          EE  08.11.11  317991
# 4   SX625101        EE          AZ  17.11.11  317991

# %% [markdown]
# [Merging](https://pandas.pydata.org/docs/user_guide/merging.html) the two datasets:
#
# *Hint: Use the above questions to identify on what feature to merge the datasets*
#
# The result should contain the features flightName, Departure, Arrival,  Date, UserID, first_name, last_name, etc.

# %%
combined_dataset = pd.merge(userRecords, travelRecords, left_on="UserID", right_on='userID', how="inner", sort=False)

# %% [markdown]
# Remember, our suspect operates meticulously, ensuring that there are no null values in any entries.

# %%
combined_dataset = combined_dataset.dropna()

# %% [markdown]
# Let's now identify the users who has **travelled to** the United States (US) between the 1st of september 2019 and the 31st of october 2020.
#
# *Note that the travel date is not in datetime format.*

# %%
combined_dataset['date'] = pd.to_datetime(combined_dataset['date'], format="%d.%m.%y")

# %%
us_suspects = combined_dataset[
    (combined_dataset['destination'] == 'US') &
    (combined_dataset['date'] >= '2019-09-01') &
    (combined_dataset['date'] <= '2020-10-31')]

# %%
us_suspects_unique = us_suspects.drop_duplicates(subset=['userID'])

# %%
len(us_suspects_unique)
# Out:
# 34

# %%
us_suspects_unique.head(50)
# Out:
#        UserID  first_name  last_name   birthday country marital_status  \
# 246    468560    Ga******  Fe******* 2060-04-18      AR              1
# 463    255830   Ch*******     Be**** 2059-12-26      AT              1
# 958    861915       Ay***    Al***** 1978-02-26      AZ              0
# 2289   220420     Ma*****     So**** 1984-12-23      BR              0
# 2702   297653       Br***       Wo** 2068-09-22      CA              1
# 4089   710764     Ra*****  He******* 1976-05-27      CR              0
# 4897   267733       Sø***     Ma**** 1998-09-14      DK              0
# 5349   429697        Li**     Re**** 2059-07-28      EE              1
# 7179   649131       Ju***     Wi**** 1991-07-04      GB              1
# 7451   481578      Br****    De***** 2063-07-31      GT              1
# 7588   434361   El*******      Ra*** 1999-07-19      GT              0
# 7665   804662       Er***  He******* 2054-08-08      GT              1
# 7913   287607      Lu****      Bo*** 1973-06-07      HR              0
# 8452   411537      An****       Pa** 1972-11-27      HU              1
# 8979   424791       Fi***   Mc****** 1974-06-23      IE              1
# 9623   679196        Pu**     Ra**** 1988-07-25      IN              1
# 9990   410319  Al********    Bi***** 2067-02-10      IT              1
# 12165  556033      Ма****    Tu***** 2054-03-26      MD              1
# 14639  139646        Ka**     Ha**** 1975-03-29      NO              1
# 14875  628854    Kr******      Di*** 1986-01-04      PH              1
# 15972  762279        In**    Al***** 2055-02-18      PT              0
# 16340  638911     На*****    Во***** 1985-05-08      RU              0
# 16632  785994      Га****   Мо****** 1996-09-09      RU              1
# 16771  642133      Ni****   Sv****** 1978-05-31      SE              0
# 17222  428951      Ni****    Ni***** 2054-06-19      SE              1
# 17644  739104        Em**     Öz**** 2062-05-28      TR              1
# 17894  852352     Hü*****      Çe*** 2004-04-09      TR              1
# 18116  123699     Je*****      Pe*** 2055-03-18      US              0
# 18141  581969       Na***      Sm*** 2058-07-27      US              0
# 18283  409055       Li***       Di** 1971-05-25      US              1
# 18312  850103        Li**      Pa*** 2053-12-13      US              1
# 18362  707686        Jo**     Fl**** 1990-08-22      US              1
# 18384  942571        Lu**    Sa***** 2058-11-19      US              0
# 18707  866017       Ma***      Lo*** 2053-10-01      US              0
#
#        number_of_kids               employment flightName departure  \
# 246               2.0                   Lawyer   MG891910        AR
# 463               1.0                Professor  OO3731010        CA
# 958               1.0                   Doctor    GU84573        ES
# 2289              3.0             Web Designer   TF469810        IT
# 2702              0.0                   Lawyer    MX97137        FR
# 4089              4.0                  Manager    NY87398        BE
# 4897              0.0            Kitchen staff    HX23943        CO
# 5349              3.0  Administrative employee   JE532410        CH
# 7179              3.0                   Banker   LY781032        BR
# 7451              0.0  Administrative employee    PP35996        HU
# 7588              0.0            Kitchen staff    SA39423        BE
# 7665              1.0               Consultant  XE1036910        JP
# 7913              3.0            Kitchen staff    BF79684        RU
# 8452              4.0             Web Designer   YO910418        AR
# 8979              2.0       Teaching Assistant    IU77244        CO
# 9623              0.0                Librarian    XQ62824        CA
# 9990              0.0                   Lawyer   OS610439        JP
# 12165             2.0             Web Designer    XD18258        IT
# 14639             1.0                   Doctor    HA26526        HU
# 14875             1.0                  Manager    WQ77186        MX
# 15972             1.0                   Doctor    SH63275        AR
# 16340             2.0            Kitchen staff    DZ61923        MD
# 16632             1.0  Administrative employee    SR31584        BR
# 16771             0.0       Teaching Assistant    XB61871        SE
# 17222             4.0            Kitchen staff    KM72712        IS
# 17644             1.0                Professor  DK1015102        BG
# 17894             0.0                Professor    GZ86777        HU
# 18116             0.0                   Lawyer    PK41837        PL
# 18141             3.0                Librarian    RZ41582        HR
# 18283             0.0                Librarian    IH35877        IT
# 18312             3.0                Librarian   FB732410        MT
# 18362             2.0               Consultant    AF35718        CR
# 18384             4.0             Web Designer   QA221095        AT
# 18707             0.0                  Manager   BT519103        NL
#
#       destination       date  userID
# 246            US 2020-07-16  468560
# 463            US 2020-04-10  255830
# 958            US 2020-02-10  861915
# 2289           US 2020-03-17  220420
# 2702           US 2020-07-23  297653
# 4089           US 2019-09-17  710764
# 4897           US 2020-10-10  267733
# 5349           US 2020-06-26  429697
# 7179           US 2020-04-18  649131
# 7451           US 2020-05-03  481578
# 7588           US 2020-10-06  434361
# 7665           US 2020-01-14  804662
# 7913           US 2020-02-16  287607
# 8452           US 2020-08-19  411537
# 8979           US 2020-09-20  424791
# 9623           US 2020-01-23  679196
# 9990           US 2020-04-23  410319
# 12165          US 2019-10-13  556033
# 14639          US 2019-11-10  139646
# 14875          US 2020-07-29  628854
# 15972          US 2019-09-20  762279
# 16340          US 2020-01-09  638911
# 16632          US 2020-06-09  785994
# 16771          US 2020-08-04  642133
# 17222          US 2020-05-28  428951
# 17644          US 2020-04-21  739104
# 17894          US 2020-01-04  852352
# 18116          US 2020-07-19  123699
# 18141          US 2019-10-15  581969
# 18283          US 2020-10-07  409055
# 18312          US 2020-01-28  850103
# 18362          US 2020-01-17  707686
# 18384          US 2019-12-23  942571
# 18707          US 2020-05-09  866017

# %%
target_ids = [255830, 827670, 438132, 785994, 434361]
result = us_suspects_unique[us_suspects_unique['userID'].isin(target_ids)]
result
# Out:
#        UserID first_name last_name   birthday country marital_status  \
# 463    255830  Ch*******    Be**** 2059-12-26      AT              1
# 7588   434361  El*******     Ra*** 1999-07-19      GT              0
# 16632  785994     Га****  Мо****** 1996-09-09      RU              1
#
#        number_of_kids               employment flightName departure  \
# 463               1.0                Professor  OO3731010        CA
# 7588              0.0            Kitchen staff    SA39423        BE
# 16632             1.0  Administrative employee    SR31584        BR
#
#       destination       date  userID
# 463            US 2020-04-10  255830
# 7588           US 2020-10-06  434361
# 16632          US 2020-06-09  785994

# %% [markdown]
# **Q6. How many suspects travelled to the US between the 1st of September 2019 and the 31st of October 2020?**

# %% [markdown]
# **Q7. Which users are included in the remaining list of suspects who traveled to the US between the 1st of September 2019 and the 31st of October 2020?** Choose from the answers on Moodle.

# %% [markdown]
# ## [Data visualisation ](https://pandas.pydata.org/docs/user_guide/visualization.html)
#
#  Suisse Impossible Mission Force is happy with the result and would like to have some visual aid to make a profile of the potential suspects.

# %% [markdown]
# Let's create a pie chart to visualize the employment distribution among the suspects who traveled to US between September 1st, 2019, and October 31st, 2020.

# %%
employment_counts = us_suspects_unique['employment'].value_counts()
series = pd.Series(employment_counts.to_list(), index=employment_counts.index.to_list())
series.plot.pie(autopct="%.2f", figsize=(6, 6))
# Out:
# <Axes: >

# %% [markdown]
# **Q8. Which profession is the least represented among the suspects who traveled to US between September 1st, 2019, and October 31st, 2020?**
#  Choose from the answers on Moodle.

# %% [markdown]
# ## Journey length
#
# The Suisse Impossible Mission Force suspects that the rogue agent is an anomaly within his declared employment category, particularly in terms of the number of days he spent at destinations compared to his peers.
#
# To identify such deviations, we can employ boxplots for each employment category, allowing us to visually identify outliers in the data.

# %% [markdown]
# First, let's construct two tables: one for the dates of arrival and another for the dates of departure. Utilize the existing dataset to extract these dates based on the 'destination' and 'departure' columns. Ensure that both the arrival and departure dates are within the period the suspect is believed to have been in the US, which is from September 2019 to October 2020.

# %%
# For this step we will need the information not only about the fights to the US,
# but also about the flights taken from the US
# Your code here

# %% [markdown]
# We can keep on both of these tables the user ID, employment, and departure date / arrival date.

# %%
#Your code here

# %% [markdown]
# We can now join the two tables on user ID.

# %%
#Your code here

# %% [markdown]
# We can now create a new feature called journey_length representing the difference between departure date and arrival date.
#
# *Hint: Ensure that the journey_length is in the right format*

# %%
#Your code here

# %% [markdown]
# *Sidenote: if you get negative journey length, what would be your explanation to that?*

# %% [markdown]
# We can now create the boxplots where the x-axis represents each profession and the y-axis corresponds to the journey length.

# %%
#Your code here

# %% [markdown]
# **Q9. Which profession has the most staggering outlier?**
# (Meaning that the outlier value is the farthest away from the corresponding boxplot.)

# %% [markdown]
# ### SIMF is satisfied with your work but believes the current data is inconclusive.
#
# Your investigation will continue when more intelligence comes in...

# %% [markdown]
# **Don't forget to complete the moodle quiz ([Assignment Q1](https://moodle.unil.ch/mod/quiz/view.php?id=1744562)) and submit your code ([Code Q1](https://moodle.unil.ch/mod/assign/view.php?id=1744563)) on Moodle before Monday 30.09.2024.**
